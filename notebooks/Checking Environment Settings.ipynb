# %%
# !conda list
# Out:
# # packages in environment at C:\Users\ual-laptop\anaconda3\envs\nlpproj:
# #
# # Name                    Version                   Build  Channel
# absl-py                   2.1.0                    pypi_0    pypi
# aiohappyeyeballs          2.4.4                    pypi_0    pypi
# aiohttp                   3.11.10                  pypi_0    pypi
# aiosignal                 1.3.1                    pypi_0    pypi
# annotated-types           0.7.0                    pypi_0    pypi
# anyio                     4.6.2           py310haa95532_0
# argon2-cffi               21.3.0             pyhd3eb1b0_0
# argon2-cffi-bindings      21.2.0          py310h2bbff1b_0
# array-record              0.4.1                    pypi_0    pypi
# arrow                     1.3.0                    pypi_0    pypi
# asttokens                 2.0.5              pyhd3eb1b0_0
# astunparse                1.6.3                    pypi_0    pypi
# async-lru                 2.0.4           py310haa95532_0
# ...

# %%
from bigbench.bbseqio import task_api
